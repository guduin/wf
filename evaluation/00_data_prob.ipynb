# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from tensorflow.keras.utils import to_categorical
from keras.models import load_model
import random as rd
import collections as clt

# %%
import module
import importlib
importlib.reload(module)
# Out:
# <module 'module' from 'C:\\Users\\Admin\\Documents\\Anaconda\\Project6\\module.py'>

# %%
train_data, train_index, test_data, test_index = module.load_data('F:/data_edge/3_data/data.csv')
# Out:
# data shape: (10000, 1002)
# train data shape: (8000, 500)
# test data shape: (2000, 500)

# %%
size_list, size_count, size_list_count = module.get_list(train_data)

# %%
size_list
# Out:
# array([-1494,    54,   -54,    66, -1466,   -66,   571, -1078, -1478,
#          -92,   147,   -85, -1270,  -182, -1294,   134, -1203,  -328,
#          -88,   139, -1366,  -341, -1334,    74,   153,   -59,    92,
#         -304,   -82,  -188,  1494,  -312,   -84, -1486,  -123,   -80,
#          148,   146,  -627,   105,    97,   162,   500,  -325,  -309,
#          129,    85, -1458,   -63,   180,  -116,  -210,  -202, -1238,
#           82,  -310,   145,   163,  -518,   130,   131,   -81, -1482,
#         -791,   161, -1075,   118,   122,  -102,  -132,   140,  -351,
#         -687,   528, -1068,  -801,   -78,   575,   154, -1338,   127,
#        -1292,  -357, -1483,   -96,   -56,   526,   124,   730,  -392,
#         -359,  -280,  1458,   762,   486,  -115,   143,   132, -1002,
#          733,  -438,   128, -1308,    90,   155,  -601,   761,  -523,
#          -60,  -912,  -629,  -440,  -602,   -65,  -349,  -365,   527,
# ...

# %%
size_count
# Out:
# array([884846, 503424,  98859,  66870,  47403,  46023,  20337,  18247,
#         11646,  10528,  10239,   8704,   8259,   6583,   5988,   5672,
#          5586,   4970,   4702,   4675,   4591,   4517,   4384,   4163,
#          4018,   3755,   3614,   3566,   3290,   2856,   2555,   2450,
#          2446,   2418,   2342,   2324,   2254,   2246,   2029,   1964,
#          1953,   1938,   1874,   1850,   1783,   1682,   1675,   1667,
#          1659,   1623,   1623,   1617,   1566,   1515,   1426,   1401,
#          1365,   1340,   1304,   1250,   1245,   1229,   1227,   1194,
#          1144,   1141,   1129,   1120,   1103,   1042,   1016,   1005,
#          1004,    978,    966,    943,    912,    897,    894,    893,
#           885,    885,    868,    860,    855,    853,    847,    836,
#           834,    821,    819,    805,    800,    789,    787,    787,
#           782,    768,    757,    751,    749,    747,    737,    735,
# ...

# %%
plt.plot(size_count[0:20]/sum(size_count), 'o-')
plt.xticks(np.linspace(0, 20, 20), size_list[0:19], rotation=90)
plt.xlabel('Packet Size')
plt.ylabel('Probability')
# Out:
# Text(0,0.5,'Probability')
