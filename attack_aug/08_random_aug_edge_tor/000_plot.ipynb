# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
res_tcp_ramdom = np.load('data/res_tcp_ramdom.npy')
res_tcp_ramdom_aug = np.load('data/res_tcp_ramdom_aug.npy')
res_tcp_mtu = np.load('data/res_tcp_mtu.npy')
res_tcp_mtu_aug = np.load('data/res_tcp_mtu_aug.npy')
res_tcp_split = np.load('data/res_tcp_split.npy')
res_tcp_split_aug = np.load('data/res_tcp_split_aug.npy')

# %%
plt.figure(figsize=(6,5))

x = np.linspace(0, 1, num=21, endpoint=True)

plt.plot(x, res_tcp_ramdom, 'ro-')
plt.plot(x, res_tcp_ramdom_aug, 'r^--')
plt.plot(x, res_tcp_mtu, 'go-')
plt.plot(x, res_tcp_mtu_aug, 'g^--')
plt.plot(x, res_tcp_split, 'bo-')
plt.plot(x, res_tcp_split_aug, 'b^--')

plt.xlabel('Random Packets Probability', fontsize=18)
plt.ylabel('WF Attack Accuracy', fontsize=18)
plt.xlim((0, 1))
plt.ylim((0, 1))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(['RPD Insert', '3A Insert', 'RPD MTU', '3A MTU', 'RPD Split', '3A Split'], loc=4)
plt.savefig('C:/Users/Admin/Desktop/random_aug_edge.pdf', bbox_inches = 'tight')

# %%
print(len(res_tcp_ramdom) / sum(res_tcp_ramdom))
print(len(res_tcp_ramdom_aug) / sum(res_tcp_ramdom_aug))
print(len(res_tcp_mtu) / sum(res_tcp_mtu))
print(len(res_tcp_mtu_aug) / sum(res_tcp_mtu_aug))
print(len(res_tcp_split) / sum(res_tcp_split))
print(len(res_tcp_split_aug) / sum(res_tcp_split_aug))
# Out:
# 6.820396280190172
# 1.1644240727525499
# 1.3899307275897623
# 1.0559308000061847
# 6.010876783253186
# 1.064225139278106

# %%
res_tor_ramdom = np.load('data/res_tor_ramdom.npy')
res_tor_ramdom_aug = np.load('data/res_tor_ramdom_aug.npy')
res_tor_walkietalkie = np.load('data/res_tor_walkietalkie.npy')
res_tor_walkietalkie_aug = np.load('data/res_tor_walkietalkie_aug.npy')
res_tor_wtfpad = np.load('data/res_tor_wtfpad.npy')
res_tor_wtfpad_aug = np.load('data/res_tor_wtfpad_aug.npy')

# %%
plt.figure(figsize=(6,5))

x = np.linspace(0, 1, num=21, endpoint=True)

plt.plot(x, res_tor_ramdom, 'ro-')
plt.plot(x, res_tor_ramdom_aug, 'r^--')
plt.plot(x, res_tor_walkietalkie, 'go-')
plt.plot(x, res_tor_walkietalkie_aug, 'g^--')
plt.plot(x, res_tor_wtfpad, 'bo-')
plt.plot(x, res_tor_wtfpad_aug, 'b^--')

plt.xlabel('Random Packets Probability', fontsize=18)
plt.ylabel('WF Attack Accuracy', fontsize=18)
plt.xlim((0, 1))
plt.ylim((0, 1))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(['RCD Insert', '3A Insert', 'Walkie-Talkie', '3A Walkie-Talkie', 'WTF-PAD', '3A WTF-PAD'], loc=4)
plt.savefig('C:/Users/Admin/Desktop/aug_tor.pdf', bbox_inches = 'tight')

# %%
print(len(res_tor_ramdom) / sum(res_tor_ramdom))
print(len(res_tor_ramdom_aug) / sum(res_tor_ramdom_aug))
print(len(res_tor_walkietalkie) / sum(res_tor_walkietalkie))
print(len(res_tor_walkietalkie_aug) / sum(res_tor_walkietalkie_aug))
print(len(res_tor_wtfpad) / sum(res_tor_wtfpad))
print(len(res_tor_wtfpad_aug) / sum(res_tor_wtfpad_aug))
# Out:
# 4.877035057447179
# 1.1711664115405183
# 3.8434122348390085
# 1.1050672343535903
# 4.970847589445516
# 1.2181197678678777
