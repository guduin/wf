# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
insert = [1.58, 1.37, 1.22, 1.22, 1.16, 1.16]
mtu = [1.08, 1.06, 1.06, 1.06, 1.06, 1.05]
split = [1.43, 1.22, 1.1, 1.07, 1.06, 1.04]

# %%
plt.figure(figsize=(7,5))
plt.bar(0, insert[0], width=1, color = 'r', zorder=100) #1
plt.bar(1, mtu[0]   , width=1, color = 'g', zorder=100)
plt.bar(2, split[0], width=1, color = 'b', zorder=100)

plt.bar(4, insert[1],width=1, color = 'r', zorder=100) #0.4
plt.bar(5, mtu[1]   ,width=1, color = 'g', zorder=100)
plt.bar(6, split[1],  width=1, color = 'b', zorder=100)

plt.bar(8, insert[2],width=1, color = 'r', zorder=100) #0.6
plt.bar(9, mtu[2]   ,width=1, color = 'g', zorder=100)
plt.bar(10,split[2],  width=1, color = 'b', zorder=100)

plt.bar(12, insert[2],width=1, color = 'r', zorder=100) #0.6
plt.bar(13, mtu[2]   ,width=1, color = 'g', zorder=100)
plt.bar(14,split[2],  width=1, color = 'b', zorder=100)

plt.bar(16, insert[2],width=1, color = 'r', zorder=100) #0.6
plt.bar(17, mtu[2]   ,width=1, color = 'g', zorder=100)
plt.bar(18,split[2],  width=1, color = 'b', zorder=100)

plt.bar(20, insert[2],width=1, color = 'r', zorder=100) #0.6
plt.bar(21, mtu[2]   ,width=1, color = 'g', zorder=100)
plt.bar(22,split[2],  width=1, color = 'b', zorder=100)

plt.legend(['RPD Insert', 'RPD MTU', 'RPD Split'], fontsize=14)
plt.xticks([1, 5, 9, 13, 17, 21], ['1', '2', '3', '4', '5', '6'])
plt.xlabel('Repeat Times', fontsize=18)
plt.ylabel('Defensive Efficiency (DE)', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.ylim((0.4, 1.8))
# plt.xlim((-3, 13))
plt.savefig('C:/Users/Admin/Desktop/3a_repeat.pdf', bbox_inches = 'tight')
